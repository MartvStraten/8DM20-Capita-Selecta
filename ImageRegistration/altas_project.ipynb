# %% [markdown]
# ## Atlas Based Registration Project
# In this notebook, the registration pipeline of the baseline model is combined in a more compact code. This makes it easier to register a series of atlas images (training data) to the fixed image (validation data). Only the `ELASTIC_PATH` and `TRANSFORMIX_PATH` need to be changed based on your own directory. Make sure that the DevelopmentData folder is filled with the patient folders: p102, p107, etc.

# %%
# Library imports
import matplotlib.pyplot as plt
import imageio.v3 as iio
import numpy as np
import elastix
import os

from sklearn.model_selection import train_test_split

# General file paths
BASE_PATH = "../DevelopmentData"
MR_PATHS = [os.path.join(BASE_PATH, f, "mr_bffe.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')]
MASK_PATHS = [os.path.join(BASE_PATH, f, "prostaat.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')]

# Change these paths based on own directory!
folder_path = r'C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/'
ELASTIX_PATH = os.path.join(folder_path,'elastix-5.0.0-win64/elastix.exe')
TRANSFORMIX_PATH = os.path.join(folder_path,'elastix-5.0.0-win64/transformix.exe')

if not os.path.exists(ELASTIX_PATH):
    raise IOError('Elastix cannot be found, please set the correct ELASTIX_PATH.')
if not os.path.exists(TRANSFORMIX_PATH):
    raise IOError('Transformix cannot be found, please set the correct TRANSFORMIX_PATH.')

# %% [markdown]
# The following code splits the data paths into a training (n=10) and validation (n=5) set in order to assess the performance of the atlas-based registration method for obtaining prostate segmentations. This split is performed three times to generate extra segmentations.

# %%
# Train test split
# mr_train_paths, mr_test_paths, mask_train_paths, mask_test_paths = train_test_split(MR_PATHS, MASK_PATHS, test_size=0.333, shuffle=False)

# %%
split_size = 5  # Each test set contains 5 images and 5 masks
num_splits = len(MR_PATHS) // split_size  # Determine the number of splits (3 splits for 15 images)

# Initialize lists to hold the results of each split
mr_train_splits = []
mr_test_splits = []
mask_train_splits = []
mask_test_splits = []

# Perform the splits manually
for i in range(num_splits):
    # The starting index for the test set in this iteration
    test_start = i * split_size
    test_end = test_start + split_size
    
    # Define the test set
    mr_test = MR_PATHS[test_start:test_end]
    mask_test = MASK_PATHS[test_start:test_end]
    
    # Define the train set (everything not in the test set)
    mr_train = MR_PATHS[:test_start] + MR_PATHS[test_end:]
    mask_train = MASK_PATHS[:test_start] + MASK_PATHS[test_end:]
    
    # Append the results for this split
    mr_train_splits.append(mr_train)
    mr_test_splits.append(mr_test)
    mask_train_splits.append(mask_train)
    mask_test_splits.append(mask_test)

# %%
mr_test_splits
# Out:
# [['../DevelopmentData\\p102\\mr_bffe.mhd',
#   '../DevelopmentData\\p107\\mr_bffe.mhd',
#   '../DevelopmentData\\p108\\mr_bffe.mhd',
#   '../DevelopmentData\\p109\\mr_bffe.mhd',
#   '../DevelopmentData\\p115\\mr_bffe.mhd'],
#  ['../DevelopmentData\\p116\\mr_bffe.mhd',
#   '../DevelopmentData\\p117\\mr_bffe.mhd',
#   '../DevelopmentData\\p119\\mr_bffe.mhd',
#   '../DevelopmentData\\p120\\mr_bffe.mhd',
#   '../DevelopmentData\\p125\\mr_bffe.mhd'],
#  ['../DevelopmentData\\p127\\mr_bffe.mhd',
#   '../DevelopmentData\\p128\\mr_bffe.mhd',
#   '../DevelopmentData\\p129\\mr_bffe.mhd',
#   '../DevelopmentData\\p133\\mr_bffe.mhd',
#   '../DevelopmentData\\p135\\mr_bffe.mhd']]

# %%
# Load example of patient data
mr_example = iio.imread(mr_train_splits[0][0])
mask_example = iio.imread(mask_train_splits[0][0])

# Plot example of patient data
slice = 150
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(mr_example[:,:,slice], cmap="gray")
ax[0].set_title(f"MR prostate (slice {slice})")
ax[1].imshow(mask_example[:,:,slice], cmap="gray")
ax[1].set_title(f"Prostate mask (slice {slice})");

# %% [markdown]
# # Registration pipeline
# In the code block below, a function is defined that performs the full baseline registration process. This includes a rigid registration step for a rough initial alignment, followed by a nonlinear registration step using BSplines. Here, the fixed image represents an image with unknown mask (validation data) and the moving image is an atlas image with known mask (training data). The deformation field obtained from this registration pipeline is applied to the mask of the moving image.

# %%
def registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path):
    """
    """
    # Make a results directory if non exists
    if os.path.exists("results_baseline/rigid") is False:
        os.makedirs(os.path.join("results_baseline/rigid"))
    
    # Define a new elastix object 'el' with the correct path to elastix
    el = elastix.ElastixInterface(elastix_path=ELASTIX_PATH)

    # Execute the rigid registration step
    el.register(
        fixed_image=fixed_image_path,
        moving_image=moving_image_path,
        parameters=["parameters_baseline_rigid.txt"],
        output_dir="results_baseline/rigid"
    )   

    # Find result of rigid registration
    rigid_transformed_image_path = os.path.join('results_baseline/rigid', 'result.0.mhd')
    rigid_transform_path = os.path.join('results_baseline/rigid', 'TransformParameters.0.txt')

    # Make a new transformix object tr with the CORRECT PATH to transformix
    tr = elastix.TransformixInterface(parameters=rigid_transform_path, transformix_path=TRANSFORMIX_PATH)
    
    # Transform the mask with the transformation parameters
    rigid_transformed_mask_path = tr.transform_image(moving_mask_path, output_dir=os.path.join('results_baseline/rigid'))   

    # Make a results directory if non exists
    if os.path.exists("results_baseline/nonlinear") is False:
        os.makedirs(os.path.join("results_baseline/nonlinear"))

    # Execute the nonlinear registration step
    el.register(
        fixed_image=fixed_image_path,
        moving_image=rigid_transformed_image_path,
        parameters=["parameters_baseline_nonlinear.txt"],
        output_dir="results_baseline/nonlinear"
    )

    # Find result of nonlinear registration
    nonlinear_transform_path = os.path.join('results_baseline/nonlinear', 'TransformParameters.0.txt')

    # Make a new transformix object tr with the CORRECT PATH to transformix
    tr = elastix.TransformixInterface(parameters=nonlinear_transform_path, transformix_path=TRANSFORMIX_PATH)

    # Transform the mask with the transformation parameters
    nonlinear_transformed_mask_path = tr.transform_image(rigid_transformed_mask_path, output_dir=os.path.join('results_baseline/nonlinear'))

    return nonlinear_transformed_mask_path

# %%
# ADD AUGMENTATION IMAGES HERE

aug_mr_train_paths = [] 
aug_mask_train_paths = []

# %% [markdown]
# The registration pipeline is called iteratively to create all altas segmentations for an image in the validation set. The masks are loaded into a numpy array and used in the following processing steps.

# %%
total_atlas = []

for split_idx in range(len(mr_test_splits)):
    for test_idx in range(len(mr_test_splits[0])):
        # Loop over images in the testing set
        atlas_masks = []
        fixed_image_path = mr_test_splits[split_idx][test_idx]

        for train_idx in range(len(mr_train_splits[0])):
            # Loop over images in the training set
            moving_image_path = mr_train_splits[split_idx][train_idx]
            moving_mask_path = mask_train_splits[split_idx][train_idx]

            # Call registration pipeline and store deformed atlas masks
            new_atlas_mask_path = registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path)
            atlas_masks.append(iio.imread(new_atlas_mask_path))

        for train_idx in range(len(aug_mr_train_paths)):
            # Loop over images in the training set
            moving_image_path = aug_mr_train_paths[train_idx]
            moving_mask_path = aug_mask_train_paths[train_idx]

            # Call registration pipeline and store deformed atlas masks
            new_atlas_mask_path = registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path)
            atlas_masks.append(iio.imread(new_atlas_mask_path))
        
        atlas_masks = np.array(atlas_masks)
        total_atlas.append(atlas_masks)

# Convert to numpy array
# atlas_masks = np.array(atlas_masks)
# Out:
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p116\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p117\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p119\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p120\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p125\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p125\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# ...
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p129\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212238/OneDrive - TU Eindhoven/Documents/TUE/M - Jaar 1/Capita Selecta in MI/elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear

# %% [markdown]
# The following figure displays the original mask of the testing sample on top. The following 10 images show the deformed masks based on the atlas images in the training set

# %%
# Testing sample
slice = 150
split_idx = 2
mask_idx = 2

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mr_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"MR prostate (slice {slice})")
ax[1].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[1].set_title(f"Prostate mask (slice {slice})");

# Atlas image segmentations
fig, ax = plt.subplots(2, 5, figsize=(20, 4))
ax = ax.flatten()

for idx in range(len(atlas_masks)):
    ax[idx].imshow(total_atlas[split_size*split_idx+mask_idx][idx][:,:,slice], cmap="gray")
    ax[idx].set_title(f"Atlas mask {idx + 1}")

# %% [markdown]
# Combining the figures results in a new segmentation with values between 0 and 10. A threshold can be chosen to create the finalized segmentation.

# %%
all_total_masks = []
for i in range(len(total_atlas)):
    # for mask in atlas_masks:
    total_mask = 0
    for mask in total_atlas[i]:
        total_mask += mask
    all_total_masks.append(total_mask)

slice = 150
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"True prostate mask (slice {slice})");
ax[1].imshow(all_total_masks[split_size*split_idx+mask_idx][:,:,slice], cmap="gray")
ax[1].set_title(f"Atlas prostate mask (slice {slice})");

# %%
# threshold_mask = total_mask > 6.5
threshold_mask = all_total_masks[split_size*split_idx+mask_idx] > 4.5

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"True prostate mask (slice {slice})");
ax[1].imshow(threshold_mask[:,:,slice], cmap="gray")
ax[1].set_title(f"Atlas prostate mask (slice {slice})");

# %%
def dice_coefficient(mask1, mask2):
    if mask1.shape != mask2.shape:
        raise ValueError("Input masks must have the same shape.")
    
    intersection = np.sum(mask1*mask2)
    volume_sum = np.sum(mask1) + np.sum(mask2)

    if volume_sum == 0:
        return 1.0  # If both masks are empty, they are considered identical
    
    return 2.0 * intersection / volume_sum

print("Dice coefficient:", dice_coefficient(iio.imread(mask_test_splits[split_idx][mask_idx]), threshold_mask))
# Out:
# Dice coefficient: 0.9338088413380884

# %%
# flatten the mask test split paths
mask_test_paths = [element for innerList in mask_test_splits for element in innerList]
mask_test_paths
# Out:
# ['../DevelopmentData\\p102\\prostaat.mhd',
#  '../DevelopmentData\\p107\\prostaat.mhd',
#  '../DevelopmentData\\p108\\prostaat.mhd',
#  '../DevelopmentData\\p109\\prostaat.mhd',
#  '../DevelopmentData\\p115\\prostaat.mhd',
#  '../DevelopmentData\\p116\\prostaat.mhd',
#  '../DevelopmentData\\p117\\prostaat.mhd',
#  '../DevelopmentData\\p119\\prostaat.mhd',
#  '../DevelopmentData\\p120\\prostaat.mhd',
#  '../DevelopmentData\\p125\\prostaat.mhd',
#  '../DevelopmentData\\p127\\prostaat.mhd',
#  '../DevelopmentData\\p128\\prostaat.mhd',
#  '../DevelopmentData\\p129\\prostaat.mhd',
#  '../DevelopmentData\\p133\\prostaat.mhd',
#  '../DevelopmentData\\p135\\prostaat.mhd']

# %%
all_dice_coefs = []

for i in range(len(all_total_masks)):
    dice_coefs = []

    for threshold in range(len(atlas_masks)+1):
        threshold_mask = all_total_masks[i] >= threshold
        dice_coefs.append(dice_coefficient(iio.imread(mask_test_paths[i]), threshold_mask))

    max_dice = max(dice_coefs)
    index = dice_coefs.index(max_dice)
    print(f"Optimum mask threshold for test image {i+1}: {index}")
    print(f"Corresponding max. dice score: {max_dice}")
    print("-----")

    all_dice_coefs.append(dice_coefs)

all_dice_coefs = np.array(all_dice_coefs)
thres_mean = np.mean(all_dice_coefs, axis=0)

tot_max_dice = max(thres_mean)
tot_index = np.where(thres_mean == tot_max_dice)[0][0]
print(f"Optimum mask threshold averaged over all test data: {tot_index}")
print(f"Corresponding max. dice score: {tot_max_dice}")
# Out:
# Optimum mask threshold for test image 1: 8
# Corresponding max. dice score: 0.8502992670142989
# -----
# Optimum mask threshold for test image 2: 7
# Corresponding max. dice score: 0.865573423560741
# -----
# Optimum mask threshold for test image 3: 5
# Corresponding max. dice score: 0.9235301670022912
# -----
# Optimum mask threshold for test image 4: 5
# Corresponding max. dice score: 0.8260800064538201
# -----
# Optimum mask threshold for test image 5: 6
# Corresponding max. dice score: 0.799094782667678
# -----
# Optimum mask threshold for test image 6: 6
# Corresponding max. dice score: 0.9275683280074077
# -----
# Optimum mask threshold for test image 7: 7
# Corresponding max. dice score: 0.8115614081189718
# -----
# Optimum mask threshold for test image 8: 6
# Corresponding max. dice score: 0.9058187084682229
# -----
# Optimum mask threshold for test image 9: 7
# Corresponding max. dice score: 0.9185617249703858
# -----
# Optimum mask threshold for test image 10: 8
# Corresponding max. dice score: 0.8556377226463104
# -----
# Optimum mask threshold for test image 11: 5
# Corresponding max. dice score: 0.7901849695190422
# -----
# Optimum mask threshold for test image 12: 6
# Corresponding max. dice score: 0.9169793636826438
# -----
# Optimum mask threshold for test image 13: 5
# Corresponding max. dice score: 0.9338088413380884
# -----
# Optimum mask threshold for test image 14: 6
# Corresponding max. dice score: 0.866845749156116
# -----
# Optimum mask threshold for test image 15: 8
# Corresponding max. dice score: 0.7996590386752547
# -----
# Optimum mask threshold averaged over all test data: 6
# Corresponding max. dice score: 0.8547869615729662

# %%
fig, ax = plt.subplots(4, 4, figsize=(20, 23))
ax = ax.flatten()

for i in range(len(all_dice_coefs)):
    ax[i].scatter(list(range(len(dice_coefs))),all_dice_coefs[i]);
    ax[i].set_title(f"Dice scores for test image {i + 1}");
    ax[i].set_xlabel("Threshold (nr of overlapping masks used)");
    ax[i].set_ylabel("Dice score");

i += 1
ax[i].scatter(list(range(len(dice_coefs))),thres_mean);
ax[i].set_title(f"Mean dice score", c='r');
ax[i].set_xlabel("Threshold (nr of overlapping masks used)");
ax[i].set_ylabel("Dice score");
