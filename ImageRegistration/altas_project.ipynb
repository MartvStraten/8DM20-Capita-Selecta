# %% [markdown]
# # Atlas Based Registration Project
# In this notebook, the registration pipeline of the baseline model is combined in a more compact code. This makes it easier to register a series of atlas images (training data) to a fixed image (validation data). Only the `FOLDER_PATH` needs to be changed based on your own directory. Make sure that the DevelopmentData folder is filled with the patient folders: p102, p107, etc.

# %%
# Library imports
import matplotlib.pyplot as plt
import imageio.v3 as iio
import numpy as np
import elastix
import os

from augmentation import *

# General file paths
BASE_PATH = "../DevelopmentData/DevelopmentData"
MR_PATHS = [os.path.join(BASE_PATH, f, "mr_bffe.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')]
MASK_PATHS = [os.path.join(BASE_PATH, f, "prostaat.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')]

# Change these paths based on own directory!
FOLDER_PATH = r'C:/Users/20212059/Documents/CapitaSelecta/'
ELASTIX_PATH = os.path.join(FOLDER_PATH,'elastix-5.0.0-win64/elastix.exe')
TRANSFORMIX_PATH = os.path.join(FOLDER_PATH,'elastix-5.0.0-win64/transformix.exe')

if not os.path.exists(ELASTIX_PATH):
    raise IOError('Elastix cannot be found, please set the correct ELASTIX_PATH.')
if not os.path.exists(TRANSFORMIX_PATH):
    raise IOError('Transformix cannot be found, please set the correct TRANSFORMIX_PATH.')

# %%
# Load example of patient data
mr_example = iio.imread(MR_PATHS[0])
mask_example = iio.imread(MASK_PATHS[0])

# Plot example of patient data
slice = 150
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(mr_example[:,:,slice], cmap="gray")
ax[0].set_title(f"MR prostate (slice {slice})")
ax[1].imshow(mask_example[:,:,slice], cmap="gray")
ax[1].set_title(f"Prostate mask (slice {slice})");

# %% [markdown]
# ## Augmented Training Data
# **The function `generate_aug_data` can be called to generate the augmented data**. If the augmented images are already generated, the image paths can be loaded directly in the next code block.

# %%
def generate_aug_data(MR_PATHS, MASK_PATHS):
    """Generates augmented data images and saves them in right folder.
    
    parameters
    MR_PATHS: list of paths to patient MR images,
    MASK_PATHS: list of paths to patient mask images.
    
    returns
    aug_mr_train_paths: list of paths to augmented patient MR images
    aug_mask_train_paths: list of paths to augmented patient mask images
    """
    aug_mr_train_paths = []
    aug_mask_train_paths = []
    for idx in range(len(MR_PATHS)):
        # Find paths to mr image and mask
        mr_path = MR_PATHS[idx]
        mask_path = MASK_PATHS[idx]

        # Random elastic deformation on both mr image and mask
        aug_mr_path, aug_mask_path = reldef(mr_path, mask_path)

        # Append paths in list
        aug_mr_train_paths.append(aug_mr_path)
        aug_mask_train_paths.append(aug_mask_path)

    return aug_mr_train_paths, aug_mask_train_paths

# Example usage
# AUG_MR_PATHS, AUG_MASK_PATHS = generate_aug_data(MR_PATHS, MASK_PATHS)

# %% [markdown]
# Set the variable `use_augment_data` to True if you want to run an experiment with augmented data. Set this variable to False if you want to run the baseline experiment without augmented data. Change the variable `augment_type` based on the type of augmentation used. An overview of the options is given below:
# - Normalize: `norm`
# - Random elastic deformation: `reldef`
# - Random gamma: `rgam`
# - Random rotation: `rot`
# - Rescale: `rescale`

# %%
# Augmentation settings
use_augment_data = True
augment_type = "reldef"

# Load all augmented MR images and augmented masks
if use_augment_data and (augment_type == "reldef" or augment_type == "rot" or augment_type == "rescale" or augment_type == "affine"):
    AUG_MR_PATHS = [os.path.join(BASE_PATH, f, f"mr_bffe_aug_{augment_type}.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')] 
    AUG_MASK_PATHS = [os.path.join(BASE_PATH, f, f"prostaat_aug_{augment_type}.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')]  

# Load all augmented MR images without augmented masks
if use_augment_data and (augment_type == "norm" or augment_type == "rgam"):
    AUG_MR_PATHS = [os.path.join(BASE_PATH, f, f"mr_bffe_aug_{augment_type}.mhd") for f in os.listdir(BASE_PATH) if not f.startswith('.')] 
    AUG_MASK_PATHS = MASK_PATHS

# %%
# Load example of augmented patient data
if use_augment_data:
    aug_mr_example = iio.imread(AUG_MR_PATHS[0])
    aug_mask_example = iio.imread(AUG_MASK_PATHS[0])

    # Plot example of augmented patient data
    slice = 150
    fig, ax = plt.subplots(2, 2, figsize=(15, 5))
    ax = ax.flatten()
    ax[0].imshow(mr_example[:,:,slice], cmap="gray")
    ax[0].set_title(f"Original MR prostate (slice {slice})")
    ax[1].imshow(mask_example[:,:,slice], cmap="gray")
    ax[1].set_title(f"Original prostate mask (slice {slice})");
    ax[2].imshow(aug_mr_example[:,:,slice], cmap="gray")
    ax[2].set_title(f"Augmented MR prostate (slice {slice})")
    ax[3].imshow(aug_mask_example[:,:,slice], cmap="gray")
    ax[3].set_title(f"Augmented prostate mask (slice {slice})");

# %% [markdown]
# The following code splits the data paths into a training and validation set in order to assess the performance of the atlas-based registration method for obtaining prostate segmentations. This split is performed three times to perform cross-validation.

# %%
split_size = 5  # Each test set contains 5 images and 5 masks
num_splits = len(MR_PATHS) // split_size  # Determine the number of splits (3 splits for 15 images)

# Initialize lists to hold the results of each split
mr_train_splits = []
mr_test_splits = []
mask_train_splits = []
mask_test_splits = []
if use_augment_data:
    aug_mr_train_splits = []
    aug_mask_train_splits = []

# Perform the splits manually
for i in range(num_splits):
    # The starting index for the test set in this iteration
    test_start = i * split_size
    test_end = test_start + split_size
    
    # Append the results for this split
    mr_train_splits.append(MR_PATHS[:test_start] + MR_PATHS[test_end:])
    mr_test_splits.append(MR_PATHS[test_start:test_end])
    mask_train_splits.append(MASK_PATHS[:test_start] + MASK_PATHS[test_end:])
    mask_test_splits.append(MASK_PATHS[test_start:test_end])

    # Additional training samples if augmented data is used
    if use_augment_data:
        aug_mr_train_splits.append(AUG_MR_PATHS[:test_start] + AUG_MR_PATHS[test_end:])
        aug_mask_train_splits.append(AUG_MASK_PATHS[:test_start] + AUG_MASK_PATHS[test_end:])

# %%
mr_test_splits
# Out:
# [['../DevelopmentData\\p102\\mr_bffe.mhd',
#   '../DevelopmentData\\p107\\mr_bffe.mhd',
#   '../DevelopmentData\\p108\\mr_bffe.mhd',
#   '../DevelopmentData\\p109\\mr_bffe.mhd',
#   '../DevelopmentData\\p115\\mr_bffe.mhd'],
#  ['../DevelopmentData\\p116\\mr_bffe.mhd',
#   '../DevelopmentData\\p117\\mr_bffe.mhd',
#   '../DevelopmentData\\p119\\mr_bffe.mhd',
#   '../DevelopmentData\\p120\\mr_bffe.mhd',
#   '../DevelopmentData\\p125\\mr_bffe.mhd'],
#  ['../DevelopmentData\\p127\\mr_bffe.mhd',
#   '../DevelopmentData\\p128\\mr_bffe.mhd',
#   '../DevelopmentData\\p129\\mr_bffe.mhd',
#   '../DevelopmentData\\p133\\mr_bffe.mhd',
#   '../DevelopmentData\\p135\\mr_bffe.mhd']]

# %% [markdown]
# ## Registration pipeline
# In the code block below, a function is defined that performs the full baseline registration process. This includes a rigid registration step for a rough initial alignment, followed by a nonlinear registration step using BSplines. Here, the fixed image represents an image with unknown mask (validation data) and the moving image is an atlas image with known mask (training data). The deformation field obtained from this registration pipeline is applied to the mask of the moving image.

# %%
def registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path):
    """
    """
    # Make a results directory if non exists
    if os.path.exists("results_baseline/rigid") is False:
        os.makedirs(os.path.join("results_baseline/rigid"))
    
    # Define a new elastix object 'el' with the correct path to elastix
    el = elastix.ElastixInterface(elastix_path=ELASTIX_PATH)

    # Execute the rigid registration step
    el.register(
        fixed_image=fixed_image_path,
        moving_image=moving_image_path,
        parameters=["parameters_baseline_rigid.txt"],
        output_dir="results_baseline/rigid"
    )   

    # Find result of rigid registration
    rigid_transformed_image_path = os.path.join('results_baseline/rigid', 'result.0.mhd')
    rigid_transform_path = os.path.join('results_baseline/rigid', 'TransformParameters.0.txt')

    # Make a new transformix object tr with the CORRECT PATH to transformix
    tr = elastix.TransformixInterface(parameters=rigid_transform_path, transformix_path=TRANSFORMIX_PATH)
    
    # Transform the mask with the transformation parameters
    rigid_transformed_mask_path = tr.transform_image(moving_mask_path, output_dir=os.path.join('results_baseline/rigid'))   

    # Make a results directory if non exists
    if os.path.exists("results_baseline/nonlinear") is False:
        os.makedirs(os.path.join("results_baseline/nonlinear"))

    # Execute the nonlinear registration step
    el.register(
        fixed_image=fixed_image_path,
        moving_image=rigid_transformed_image_path,
        parameters=["parameters_baseline_nonlinear.txt"],
        output_dir="results_baseline/nonlinear"
    )

    # Find result of nonlinear registration
    nonlinear_transform_path = os.path.join('results_baseline/nonlinear', 'TransformParameters.0.txt')

    # Make a new transformix object tr with the CORRECT PATH to transformix
    tr = elastix.TransformixInterface(parameters=nonlinear_transform_path, transformix_path=TRANSFORMIX_PATH)

    # Transform the mask with the transformation parameters
    nonlinear_transformed_mask_path = tr.transform_image(rigid_transformed_mask_path, output_dir=os.path.join('results_baseline/nonlinear'))

    return nonlinear_transformed_mask_path

# %% [markdown]
# The registration pipeline is called iteratively to create all altas segmentations for an image in the validation set. The masks are loaded into a numpy array and used in the following processing steps.

# %%
total_atlas = []

for split_idx in range(len(mr_test_splits)):
    for test_idx in range(len(mr_test_splits[0])):
        # Loop over images in the testing set
        atlas_masks = []
        fixed_image_path = mr_test_splits[split_idx][test_idx]

        for train_idx in range(len(mr_train_splits[0])):
            # Loop over images in the training set
            moving_image_path = mr_train_splits[split_idx][train_idx]
            moving_mask_path = mask_train_splits[split_idx][train_idx]

            # Call registration pipeline and store deformed atlas masks
            new_atlas_mask_path = registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path)
            atlas_masks.append(iio.imread(new_atlas_mask_path))

        if use_augment_data:
            for train_idx in range(len(aug_mr_train_splits[0])):
                # Loop over images in the training set
                moving_image_path = aug_mr_train_splits[split_idx][train_idx]
                moving_mask_path = aug_mask_train_splits[split_idx][train_idx]

                # Call registration pipeline and store deformed atlas masks
                new_atlas_mask_path = registration_pipeline(fixed_image_path, moving_image_path, moving_mask_path)
                atlas_masks.append(iio.imread(new_atlas_mask_path))
        
        atlas_masks = np.array(atlas_masks)
        total_atlas.append(atlas_masks)

        print(f"Finished split {split_idx + 1} - test sample {test_idx + 1}")

# Convert to numpy array
total_atlas = np.array(total_atlas)
# Out:
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p102\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 1 - test sample 1
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p107\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 1 - test sample 2
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p108\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 1 - test sample 3
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p109\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 1 - test sample 4
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p127\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p128\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p129\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p133\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p115\mr_bffe.mhd -m ../DevelopmentData\p135\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# ...
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p133\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 3 - test sample 4
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p102\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p107\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p108\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p109\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p115\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p116\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p117\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p119\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p120\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m ../DevelopmentData\p125\mr_bffe_aug_reldef.mhd -p parameters_baseline_rigid.txt -out results_baseline/rigid
# C:/Users/20212077/OneDrive - TU Eindhoven/Desktop/8DM20 - Capita Selecta Medical Imaging\elastix-5.0.0-win64/elastix.exe -f ../DevelopmentData\p135\mr_bffe.mhd -m results_baseline/rigid\result.0.mhd -p parameters_baseline_nonlinear.txt -out results_baseline/nonlinear
# Finished split 3 - test sample 5

# %% [markdown]
# ## Results
# The following figure displays the original mask of the validation sample on top. The following images show the deformed masks based on the atlas images in the training set. It will show ten images if the baseline model experiment is run and 20 images if data augmentation is turned on.

# %%
# Testing sample
slice = 150
split_idx = 2
mask_idx = 2

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mr_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"MR prostate (slice {slice})")
ax[1].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[1].set_title(f"Prostate mask (slice {slice})");

# Atlas image segmentations
if use_augment_data:
    fig, ax = plt.subplots(4, 5, figsize=(20, 8))
else:
    fig, ax = plt.subplots(2, 5, figsize=(20, 4))
ax = ax.flatten()

for idx in range(len(atlas_masks)):
    ax[idx].imshow(total_atlas[split_size*split_idx+mask_idx][idx][:,:,slice], cmap="gray")
    ax[idx].set_title(f"Atlas mask {idx + 1}")

# %% [markdown]
# Combining the figures results in a new segmentation with values between 0 and 10 for the baseline experiment or 0 and 20 for augmented data experiments. A threshold can be chosen to create the finalized segmentation.

# %%
all_total_masks = []
for i in range(len(total_atlas)):
    # for mask in atlas_masks:
    total_mask = 0
    for mask in total_atlas[i]:
        total_mask += mask
    all_total_masks.append(total_mask)

slice = 150
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"True prostate mask (slice {slice})");
ax[1].imshow(all_total_masks[split_size*split_idx+mask_idx][:,:,slice], cmap="gray")
ax[1].set_title(f"Atlas prostate mask (slice {slice})");

# %%
# Apply a threshold to create binary mask
threshold_mask = all_total_masks[split_size*split_idx+mask_idx] >= 8

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(iio.imread(mask_test_splits[split_idx][mask_idx])[:,:,slice], cmap="gray")
ax[0].set_title(f"True prostate mask (slice {slice})");
ax[1].imshow(threshold_mask[:,:,slice], cmap="gray")
ax[1].set_title(f"Atlas prostate mask (slice {slice})");

# %% [markdown]
# ## Dice coefficient

# %%
def dice_coefficient(mask1, mask2):
    if mask1.shape != mask2.shape:
        raise ValueError("Input masks must have the same shape.")
    
    intersection = np.sum(mask1*mask2)
    volume_sum = np.sum(mask1) + np.sum(mask2)

    if volume_sum == 0:
        return 1.0  # If both masks are empty, they are considered identical
    
    return 2.0 * intersection / volume_sum

print("Dice coefficient:", dice_coefficient(iio.imread(mask_test_splits[split_idx][mask_idx]), threshold_mask))
# Out:
# Dice coefficient: 0.9345894799582775

# %%
# flatten the mask test split paths
mask_test_paths = [element for innerList in mask_test_splits for element in innerList]
mask_test_paths
# Out:
# ['../DevelopmentData\\p102\\prostaat.mhd',
#  '../DevelopmentData\\p107\\prostaat.mhd',
#  '../DevelopmentData\\p108\\prostaat.mhd',
#  '../DevelopmentData\\p109\\prostaat.mhd',
#  '../DevelopmentData\\p115\\prostaat.mhd',
#  '../DevelopmentData\\p116\\prostaat.mhd',
#  '../DevelopmentData\\p117\\prostaat.mhd',
#  '../DevelopmentData\\p119\\prostaat.mhd',
#  '../DevelopmentData\\p120\\prostaat.mhd',
#  '../DevelopmentData\\p125\\prostaat.mhd',
#  '../DevelopmentData\\p127\\prostaat.mhd',
#  '../DevelopmentData\\p128\\prostaat.mhd',
#  '../DevelopmentData\\p129\\prostaat.mhd',
#  '../DevelopmentData\\p133\\prostaat.mhd',
#  '../DevelopmentData\\p135\\prostaat.mhd']

# %%
all_dice_coefs = []

for i in range(len(all_total_masks)):
    dice_coefs = []

    for threshold in range(len(atlas_masks)+1):
        threshold_mask = all_total_masks[i] >= threshold
        dice_coefs.append(dice_coefficient(iio.imread(mask_test_paths[i]), threshold_mask))

    max_dice = max(dice_coefs)
    index = dice_coefs.index(max_dice)
    print(f"Optimum mask threshold for test image {i+1}: {index}")
    print(f"Corresponding max. dice score: {max_dice}")
    print("-----")

    all_dice_coefs.append(dice_coefs)

all_dice_coefs = np.array(all_dice_coefs)
thres_mean = np.mean(all_dice_coefs, axis=0)

tot_max_dice = max(thres_mean)
tot_index = np.where(thres_mean == tot_max_dice)[0][0]
print(f"Optimum mask threshold averaged over all test data: {tot_index}")
print(f"Corresponding max. dice score: {tot_max_dice}")
# Out:
# Optimum mask threshold for test image 1: 14
# Corresponding max. dice score: 0.8525802192236732
# -----
# Optimum mask threshold for test image 2: 13
# Corresponding max. dice score: 0.8732757830871499
# -----
# Optimum mask threshold for test image 3: 9
# Corresponding max. dice score: 0.9222133482671256
# -----
# Optimum mask threshold for test image 4: 9
# Corresponding max. dice score: 0.8238110592629997
# -----
# Optimum mask threshold for test image 5: 11
# Corresponding max. dice score: 0.8198727993363444
# -----
# Optimum mask threshold for test image 6: 10
# Corresponding max. dice score: 0.9276268799681081
# -----
# Optimum mask threshold for test image 7: 12
# Corresponding max. dice score: 0.8210553345704195
# -----
# Optimum mask threshold for test image 8: 10
# Corresponding max. dice score: 0.8873875510031116
# -----
# Optimum mask threshold for test image 9: 11
# Corresponding max. dice score: 0.9023614795974302
# -----
# Optimum mask threshold for test image 10: 13
# Corresponding max. dice score: 0.8540116803513347
# -----
# Optimum mask threshold for test image 11: 9
# Corresponding max. dice score: 0.8027144134220526
# -----
# Optimum mask threshold for test image 12: 9
# Corresponding max. dice score: 0.9118262686822458
# -----
# Optimum mask threshold for test image 13: 8
# Corresponding max. dice score: 0.9345894799582775
# -----
# Optimum mask threshold for test image 14: 12
# Corresponding max. dice score: 0.8579265811819984
# -----
# Optimum mask threshold for test image 15: 15
# Corresponding max. dice score: 0.7961753977493209
# -----
# Optimum mask threshold averaged over all test data: 11
# Corresponding max. dice score: 0.8545503026355425

# %% [markdown]
# ## Excel results

# %%
for i in range(len(all_dice_coefs)):
    print(f"Dice coefficient for test image {i+1} at threshold {tot_index}: {all_dice_coefs[i][tot_index]:.4f}")
# Out:
# Dice coefficient for test image 1 at threshold 11: 0.8267
# Dice coefficient for test image 2 at threshold 11: 0.8571
# Dice coefficient for test image 3 at threshold 11: 0.9050
# Dice coefficient for test image 4 at threshold 11: 0.8111
# Dice coefficient for test image 5 at threshold 11: 0.8199
# Dice coefficient for test image 6 at threshold 11: 0.9272
# Dice coefficient for test image 7 at threshold 11: 0.8152
# Dice coefficient for test image 8 at threshold 11: 0.8857
# Dice coefficient for test image 9 at threshold 11: 0.9024
# Dice coefficient for test image 10 at threshold 11: 0.8482
# Dice coefficient for test image 11 at threshold 11: 0.7883
# Dice coefficient for test image 12 at threshold 11: 0.9065
# Dice coefficient for test image 13 at threshold 11: 0.9099
# Dice coefficient for test image 14 at threshold 11: 0.8551
# Dice coefficient for test image 15 at threshold 11: 0.7600

# %% [markdown]
# ## Visualization thresholds

# %%
fig, ax = plt.subplots(4, 4, figsize=(20, 23))
ax = ax.flatten()

for i in range(len(all_dice_coefs)):
    ax[i].scatter(list(range(len(dice_coefs))),all_dice_coefs[i]);
    ax[i].set_title(f"Dice scores for test image {i + 1}");
    ax[i].set_xlabel("Threshold (nr of overlapping masks used)");
    ax[i].set_ylabel("Dice score")
    ax[i].set_ylim();

i += 1
ax[i].scatter(list(range(len(dice_coefs))),thres_mean);
ax[i].set_title(f"Mean dice score", c='r');
ax[i].set_xlabel("Threshold (nr of overlapping masks used)");
ax[i].set_ylabel("Dice score");
